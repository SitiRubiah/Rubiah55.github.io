# %% [markdown]
# <a href="https://colab.research.google.com/github/SitiRubiah/Rubiah55.github.io/blob/main/UAS_SITIRUBIAH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
d=pd.read_csv('/content/SupplyKantor.csv')

# %%
d

# %%
x=d['SalesRep']
y=d['Jumlah']

# %%
plt.plot(x,y, 'x')
plt.title('Supply Kantor')
plt.xlabel('Nama Sales')
plt.ylabel('Jumlah')

# %%
f=pd.read_csv('/content/transaksi2.csv')

# %%
f

# %%
x=f['Jumlah']
y=f['Total']

# %%
plt.scatter(x,y,color='blue')
plt.title('Transaksi')
plt.xlabel('Jumlah')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
a=pd.read_csv('/content/profile_pelanggan.csv')

# %%
a

# %%
x=a['Provinsi']
y=a['Total']

# %%
plt.scatter(x,y,color='green')
plt.title('Profil Pelanggan')
plt.xlabel('Provinsi')
plt.ylabel('Total')

# %%
k=pd.read_csv('/content/kebutuhan_per_bulan_2.csv')

# %%
k

# %%
x=k['tahun']
y=k['kebutuhan']

# %%
plt.scatter(x,y,color='black', linestyle='--')
plt.title('Kebutuuhan Perbulan')
plt.xlabel('Tahun')
plt.ylabel('Kebutuhan')
# Out:
# Text(0, 0.5, 'Kebutuhan')

# %%
h=pd.read_csv('/content/produk2.csv')

# %%
h
# Out:
#                                        Kode                           Barang  \
# 0                                     22704                  WRAP RED APPLES
# 1                                     21933  PINK VINTAGE PAISLEY PICNIC BAG
# 2                                     22081         RIBBON REEL FLORA  FAUNA
# 3                                     22131  FOOD CONTAINER SET 3 LOVE HEART
# 4                                     22989   SET 2 PANTRY DESIGN TEA TOWELS
# 5                                     22629              SPACEBOY LUNCH BOX
# 6  216154 LAVENDER BOTANICAL DINNER CANDLES                            25000
# 7                                     35651         VINTAGE BEAD PINK SCARF
# 8                                     22966    GINGERBREAD MAN COOKIE CUTTER
#
#      Harga
# 0   8400.0
# 1  49200.0
# 2  33000.0
# 3  82600.0
# 4  55000.0
# 5  33000.0
# 6      NaN
# 7  67200.0
# 8  49200.0

# %%
x=h['Kode']
y=h['Harga']

# %%
plt.plot(x,y,'o',color='black')
plt.title('Nama Barang')
plt.xlabel('Kode')
plt.ylabel('Harga')
# Out:
# Text(0, 0.5, 'Harga')
